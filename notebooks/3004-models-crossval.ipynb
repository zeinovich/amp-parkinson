# %%
import pandas as pd
import numpy as np
import xgboost as xgb
from sklearn.model_selection import GridSearchCV, train_test_split

# %%
def smape(estimator, X, y):
    return -(100 * np.mean(2 * np.abs(estimator.predict(X) - y) / (np.abs(y) + np.abs(estimator.predict(X)))) + 1)

# %%
df = pd.read_csv('../data/2604-prots_pepts.csv', index_col=0)
df.isna().sum().sum()
# Out:
# 0

# %%
df.columns
# Out:
# Index(['visit_id', 'visit_month', 'updrs_1', 'updrs_2', 'updrs_3', 'updrs_4',
#        'on_med', 'O00391', 'O00533', 'O00584',
#        ...
#        'YSLTYIYTGLSK', 'YTTEIIK', 'YVGGQEHFAHLLILR', 'YVMLPVADQDQCIR',
#        'YVMLPVADQDQCIR.1', 'YVNKEIQNAVNGVK', 'YWGVASFLQK', 'YYCFQGNQFLR',
#        'YYTYLIMNK', 'YYWGGQYTWDMAK'],
#       dtype='object', length=1205)

# %%
df['patient_id'] = df['visit_id'].apply(lambda x: x.split('_')[0])

# %%
cols = df.columns[:-1]
df = df[['patient_id'] + list(cols)]
df
# Out:
#      patient_id  visit_id  visit_month  updrs_1  updrs_2  updrs_3  updrs_4  \
# 0            55      55_0            0     10.0      6.0     15.0      1.0
# 1            55      55_3            3     10.0      7.0     25.0      1.0
# 2            55      55_6            6      8.0     10.0     34.0      1.0
# 3            55      55_9            9      8.0      9.0     30.0      0.0
# 4            55     55_12           12     10.0     10.0     41.0      0.0
# ...         ...       ...          ...      ...      ...      ...      ...
# 2610      65043  65043_48           48      7.0      6.0     13.0      0.0
# 2611      65043  65043_54           54      4.0      8.0     11.0      1.0
# 2612      65043  65043_60           60      6.0      6.0     16.0      1.0
# 2613      65043  65043_72           72      3.0      9.0     14.0      1.0
# 2614      65043  65043_84           84      7.0      9.0     20.0      3.0
#
#       on_med   O00391    O00533  ...  YSLTYIYTGLSK  YTTEIIK  YVGGQEHFAHLLILR  \
# 0          0  11254.3  732430.0  ...      201158.0  16492.3        3810270.0
# 1          0  11254.3  732430.0  ...      201158.0  16492.3        3810270.0
# 2          0  13163.6  630465.0  ...      171079.0  13198.8        4119520.0
# 3          1  13163.6  630465.0  ...      171079.0  13198.8        4119520.0
# 4          1  15257.6  815083.0  ...      231772.0  17873.8        5474140.0
# ...      ...      ...       ...  ...           ...      ...              ...
# 2610       0  10589.6  902434.0  ...      233567.0  14478.3        3185530.0
# 2611       0  10589.6  902434.0  ...      233567.0  14478.3        3185530.0
# 2612       0  10589.6  902434.0  ...      233567.0  14478.3        3185530.0
# 2613       0  10589.6  902434.0  ...      233567.0  14478.3        3185530.0
# 2614       0  10589.6  902434.0  ...      233567.0  14478.3        3185530.0
#
#       YVMLPVADQDQCIR  YVMLPVADQDQCIR.1  YVNKEIQNAVNGVK  YWGVASFLQK  \
# 0           106894.0          580667.0        131155.0    165851.0
# 1           106894.0          580667.0        131155.0    165851.0
# 2           113385.0          514861.0        103512.0    144607.0
# 3           113385.0          514861.0        103512.0    144607.0
# 4           116286.0          711815.0        136943.0    181763.0
# ...              ...               ...             ...         ...
# 2610         48793.0          501159.0        133992.0    170146.0
# 2611         48793.0          501159.0        133992.0    170146.0
# 2612         48793.0          501159.0        133992.0    170146.0
# 2613         48793.0          501159.0        133992.0    170146.0
# 2614         48793.0          501159.0        133992.0    170146.0
#
#       YYCFQGNQFLR  YYTYLIMNK  YYWGGQYTWDMAK
# 0        437305.0    46289.2        14898.4
# 1        437305.0    46289.2        14898.4
# 2        457891.0    40047.7        20703.9
# 3        457891.0    40047.7        20703.9
# 4        452253.0    54725.1        21841.1
# ...           ...        ...            ...
# 2610     359045.0    45780.0        17370.6
# 2611     359045.0    45780.0        17370.6
# 2612     359045.0    45780.0        17370.6
# 2613     359045.0    45780.0        17370.6
# 2614     359045.0    45780.0        17370.6
#
# [2615 rows x 1206 columns]

# %%
df.shape
# Out:
# (2615, 1206)

# %%
df_w_lag = df.join(df.groupby('patient_id')
                    .shift(1)
                    .add_suffix('_prev')
                    ).dropna()

df_w_lag.shape
# Out:
# (2367, 2411)

# %%
X = df_w_lag.drop(['patient_id', 'visit_id', 'visit_id_prev', 
                   'updrs_1', 'updrs_2', 'updrs_3', 'updrs_4'], 
                   axis=1)

y = df_w_lag[['updrs_1', 'updrs_2', 'updrs_3', 'updrs_4']]
X.columns
# Out:
# Index(['visit_month', 'on_med', 'O00391', 'O00533', 'O00584', 'O14498',
#        'O14773', 'O14791', 'O15240', 'O15394',
#        ...
#        'YSLTYIYTGLSK_prev', 'YTTEIIK_prev', 'YVGGQEHFAHLLILR_prev',
#        'YVMLPVADQDQCIR_prev', 'YVMLPVADQDQCIR.1_prev', 'YVNKEIQNAVNGVK_prev',
#        'YWGVASFLQK_prev', 'YYCFQGNQFLR_prev', 'YYTYLIMNK_prev',
#        'YYWGGQYTWDMAK_prev'],
#       dtype='object', length=2404)

# %%
num_cols = X.columns.tolist()
len(num_cols)
# Out:
# 2404

# %%
cols2remove = ['patient_id', 'visit_id', 'visit_id_prev', 'on_med', 'on_med_prev',
               'visit_month', 'visit_month_prev', 'updrs_1_prev', 'updrs_2_prev', 
               'updrs_3_prev', 'updrs_4_prev']

num_cols = [col for col in num_cols if col not in cols2remove]
len(num_cols)
# Out:
# 2396

# %%
'visit_month' in num_cols
# Out:
# False

# %%
X[num_cols] = X[num_cols].apply(lambda x: np.log10(x))
#pd.DataFrame(X.describe()).to_csv('../data/2904_log10X_stats.csv')
X[num_cols] = X[num_cols].apply(lambda x: (x - np.mean(x)) / np.std(x))
X
# Out:
#       visit_month  on_med    O00391    O00533    O00584    O14498    O14773  \
# 1               3       0  0.486069  0.385741  0.441990  0.441795  0.549940
# 2               6       0  0.528832  0.316280  0.375471  0.439353  0.464295
# 3               9       1  0.528832  0.316280  0.375471  0.439353  0.464295
# 4              12       1  0.569117  0.435283  0.470943  0.422874  0.541501
# 5              18       1  0.569117  0.435283  0.470943  0.422874  0.541501
# ...           ...     ...       ...       ...       ...       ...       ...
# 2610           48       0  0.469456  0.482455  0.513593  0.411861  0.336442
# 2611           54       0  0.469456  0.482455  0.513593  0.411861  0.336442
# 2612           60       0  0.469456  0.482455  0.513593  0.411861  0.336442
# 2613           72       0  0.469456  0.482455  0.513593  0.411861  0.336442
# 2614           84       0  0.469456  0.482455  0.513593  0.411861  0.336442
#
#         O14791    O15240    O15394  ...  YSLTYIYTGLSK_prev  YTTEIIK_prev  \
# 1     0.483844  0.436785  0.376905  ...           0.220297      0.577453
# 2     0.506552  0.400774  0.374763  ...           0.220297      0.577453
# 3     0.506552  0.400774  0.374763  ...           0.161053      0.497873
# 4     0.498940  0.353902  0.402353  ...           0.161053      0.497873
# 5     0.498940  0.353902  0.402353  ...           0.272115      0.606190
# ...        ...       ...       ...  ...                ...           ...
# 2610  0.349961  0.505576  0.502995  ...           0.301599      0.615119
# 2611  0.349961  0.505576  0.502995  ...           0.274937      0.530926
# 2612  0.349961  0.505576  0.502995  ...           0.274937      0.530926
# 2613  0.349961  0.505576  0.502995  ...           0.274937      0.530926
# 2614  0.349961  0.505576  0.502995  ...           0.274937      0.530926
#
#       YVGGQEHFAHLLILR_prev  YVMLPVADQDQCIR_prev  YVMLPVADQDQCIR.1_prev  \
# 1                 0.346282             0.574941               0.294734
# 2                 0.346282             0.574941               0.294734
# 3                 0.363638             0.590964               0.254740
# 4                 0.363638             0.590964               0.254740
# 5                 0.426867             0.597831               0.362444
# ...                    ...                  ...                    ...
# 2610              0.288574             0.371596               0.304441
# 2611              0.306453             0.361775               0.245772
# 2612              0.306453             0.361775               0.245772
# 2613              0.306453             0.361775               0.245772
# 2614              0.306453             0.361775               0.245772
#
#       YVNKEIQNAVNGVK_prev  YWGVASFLQK_prev  YYCFQGNQFLR_prev  YYTYLIMNK_prev  \
# 1                0.387742         0.360997          0.218914        0.297496
# 2                0.387742         0.360997          0.218914        0.297496
# 3                0.292672         0.309299          0.234790        0.247417
# 4                0.292672         0.309299          0.234790        0.247417
# 5                0.405087         0.395551          0.230514        0.355381
# ...                   ...              ...               ...             ...
# 2610             0.436362         0.417897          0.177742        0.415411
# 2611             0.396337         0.370640          0.150864        0.293671
# 2612             0.396337         0.370640          0.150864        0.293671
# 2613             0.396337         0.370640          0.150864        0.293671
# 2614             0.396337         0.370640          0.150864        0.293671
#
#       YYWGGQYTWDMAK_prev
# 1               0.369607
# 2               0.369607
# 3               0.462761
# 4               0.462761
# 5               0.477898
# ...                  ...
# 2610            0.463937
# 2611            0.413067
# 2612            0.413067
# 2613            0.413067
# 2614            0.413067
#
# [2367 rows x 2404 columns]

# %%
X.isna().sum().sum()
# Out:
# 0

# %%
from sklearn.feature_selection import f_regression, SelectKBest

# %%
k_best = 25
best_cols = {'updrs_1': [],
            'updrs_2': [],
            'updrs_3': [],
            'updrs_4': []}

for col in ['updrs_1', 'updrs_2', 'updrs_3', 'updrs_4']:
    KBest = SelectKBest(f_regression, k=k_best)
    KBest.fit(X, y[col])
    
    best_cols[col] = [val for i,val in enumerate(X.columns) if KBest.get_support()[i]]

best_cols
# Out:
# {'updrs_1': ['on_med',
#   'Q6UXD5',
#   'Q96BZ4',
#   'Q96S96',
#   'EAEEETTNDNGVLVLEPARK',
#   'EGDMLTLFDGDGPSAR',
#   'FIYGGCGGNR',
#   'GLSAEPGWQAK',
#   'ITSWMEPIVK',
#   'LEEQAQQIR',
#   'LEPGQQEEYYR',
#   'QQTEWQSGQR',
#   'TSTDLQVLAAR',
#   'updrs_1_prev',
#   'updrs_2_prev',
#   'updrs_3_prev',
#   'updrs_4_prev',
#   'on_med_prev',
#   'P01861_prev',
#   'Q96BZ4_prev',
#   'FIYGGCGGNR_prev',
#   'GLSAEPGWQAK_prev',
#   'ITSWMEPIVK_prev',
#   'TSTDLQVLAAR_prev',
#   'TTPPVLDSDGSFFLYSR_prev'],
#  'updrs_2': ['on_med',
#   'P01861',
#   'Q6UXD5',
#   'Q96BZ4',
#   'ASEGGFTATGQR',
#   'EAEEETTNDNGVLVLEPARK',
#   'EGDMLTLFDGDGPSAR',
#   'FIYGGCGGNR',
#   'LDIDSPPITAR',
#   'LEPGQQEEYYR',
#   'PALEDLR',
#   'THLGEALAPLSK',
#   'TSTDLQVLAAR',
#   'TTPPVLDSDGSFFLYSR',
#   'VGGVQSLGGTGALR',
#   'visit_month_prev',
#   'updrs_1_prev',
#   'updrs_2_prev',
#   'updrs_3_prev',
#   'updrs_4_prev',
#   'on_med_prev',
#   'P01861_prev',
#   'FIYGGCGGNR_prev',
#   'PALEDLR_prev',
#   'TTPPVLDSDGSFFLYSR_prev'],
#  'updrs_3': ['on_med',
#   'P01877',
#   'P06310',
#   'DSGVPDRFSGSGSGTDFTLK',
#   'FIYGGCGGNR',
#   'NFPPSQDASGDLYTTSSQLTLPATQCPDGK',
#   'PALEDLR',
#   'QLNEINYEDHK',
#   'QQETAAAETETR',
#   'visit_month_prev',
#   'updrs_1_prev',
#   'updrs_2_prev',
#   'updrs_3_prev',
#   'updrs_4_prev',
#   'on_med_prev',
#   'P01861_prev',
#   'P01877_prev',
#   'P06310_prev',
#   'DSGVPDRFSGSGSGTDFTLK_prev',
#   'HGNVAEGETKPDPDVTER_prev',
#   'NFPPSQDASGDLYTTSSQLTLPATQCPDGK_prev',
#   'PALEDLR_prev',
#   'QLNEINYEDHK_prev',
#   'QQETAAAETETR_prev',
#   'TTPPVLDSDGSFFLYSR_prev'],
#  'updrs_4': ['visit_month',
#   'on_med',
#   'APLIPMEHCTTR',
#   'CAEENCFIQK',
#   'CPFPSRPDNGFVNYPAKPTLYYK',
#   'DALSSVQESQVAQQAR',
#   'DLLLPQPDLR',
#   'DVLLEACCADGHR',
#   'DYFMPCPGR',
#   'DYVSQFEGSALGK',
#   'EFTRPEEIIFLR',
#   'LDEVKEQVAEVR',
#   'LEPGQQEEYYR',
#   'MKYWGVASFLQK',
#   'QLKEHAVEGDCDFQLLKLDGK',
#   'TSESGELHGLTTEEEFVEGIYK',
#   'visit_month_prev',
#   'updrs_1_prev',
#   'updrs_2_prev',
#   'updrs_3_prev',
#   'updrs_4_prev',
#   'on_med_prev',
#   'APLIPMEHCTTR_prev',
#   'CAEENCFIQK_prev',
#   'LEPGQQEEYYR_prev']}

# %%
xbgr_params = {'updrs_1': {'n_estimators': [100, 300, 500], 
                            'max_depth': [1, 3, 5],
                            'learning_rate': [0.01, 0.1, 0.5],
                            'colsample_bytree': [0.3, 0.5, 0.7],
                            'subsample': [0.3, 0.5, 0.7, 1],
                            'objective': ['reg:absoluteerror'],
                            'n_jobs': [2],
                            'random_state': [7656]},

                'updrs_2': {'n_estimators': [100, 300, 500], 
                            'max_depth': [1, 3, 5],
                            'learning_rate': [0.01, 0.1, 0.5],
                            'colsample_bytree': [0.3, 0.5, 0.7],
                            'subsample': [0.3, 0.5, 0.7, 1],
                            'objective': ['reg:absoluteerror'],
                            'n_jobs': [2],
                            'random_state': [7656]},

                'updrs_3': {'n_estimators': [100, 300, 500], 
                            'max_depth': [1, 3, 5],
                            'learning_rate': [0.01, 0.1, 0.5],
                            'colsample_bytree': [0.3, 0.5, 0.7],
                            'subsample': [0.3, 0.5, 0.7, 1],
                            'objective': ['reg:absoluteerror'],
                            'n_jobs': [2],
                            'random_state': [7656]},

                'updrs_4': {'n_estimators': [100, 300, 500], 
                            'max_depth': [1, 3, 5],
                            'learning_rate': [0.01, 0.1, 0.5],
                            'colsample_bytree': [0.3, 0.5, 0.7],
                            'subsample': [0.3, 0.5, 0.7, 1],
                            'objective': ['reg:absoluteerror'],
                            'n_jobs': [2],
                            'random_state': [7656]},
                            }

grids = {}

for col in y.columns:
    X_train = X[best_cols[col]]
    grid_search = GridSearchCV(xgb.XGBRegressor(), 
                               param_grid=xbgr_params[col], 
                               cv=5, 
                               scoring=smape, 
                               n_jobs=2,
                               verbose=1)

    grid_search.fit(X_train, y[col])
    grids[col] = {
                    'best_params': grid_search.best_params_, 
                    'best_score': grid_search.best_score_
                 }

    grid_data = pd.DataFrame(grid_search.cv_results_).sort_values(by='rank_test_score')[:10]
    grid_data.to_csv(f'../data/gridsearch/xgbregr/3004-{k_best}best_log-norm-lag_grid_{col}_f_regr.csv')
# Out:
# Fitting 5 folds for each of 324 candidates, totalling 1620 fits
# Fitting 5 folds for each of 324 candidates, totalling 1620 fits
# Fitting 5 folds for each of 324 candidates, totalling 1620 fits
# Fitting 5 folds for each of 324 candidates, totalling 1620 fits

# %%
grids
# Out:
# {'updrs_1': {'best_params': {'colsample_bytree': 0.7,
#    'learning_rate': 0.1,
#    'max_depth': 1,
#    'n_estimators': 300,
#    'n_jobs': 2,
#    'objective': 'reg:absoluteerror',
#    'random_state': 7656,
#    'subsample': 0.7},
#   'best_score': -47.68133968452935},
#  'updrs_2': {'best_params': {'colsample_bytree': 0.7,
#    'learning_rate': 0.1,
#    'max_depth': 1,
#    'n_estimators': 500,
#    'n_jobs': 2,
#    'objective': 'reg:absoluteerror',
#    'random_state': 7656,
#    'subsample': 0.3},
#   'best_score': -67.25991450695558},
#  'updrs_3': {'best_params': {'colsample_bytree': 0.7,
#    'learning_rate': 0.1,
#    'max_depth': 1,
#    'n_estimators': 300,
#    'n_jobs': 2,
#    'objective': 'reg:absoluteerror',
#    'random_state': 7656,
#    'subsample': 1},
#   'best_score': -53.56407427073883},
#  'updrs_4': {'best_params': {'colsample_bytree': 0.5,
#    'learning_rate': 0.1,
#    'max_depth': 1,
#    'n_estimators': 500,
#    'n_jobs': 2,
#    'objective': 'reg:absoluteerror',
#    'random_state': 7656,
#    'subsample': 0.7},
#   'best_score': -105.58684217615257}}

# %%
k_best = 100
best_cols = {'updrs_1': [],
            'updrs_2': [],
            'updrs_3': [],
            'updrs_4': []}

for col in ['updrs_1', 'updrs_2', 'updrs_3', 'updrs_4']:
    KBest = SelectKBest(f_regression, k=k_best)
    KBest.fit(X, y[col])
    
    best_cols[col] = [val for i,val in enumerate(X.columns) if KBest.get_support()[i]]

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
xbgr_params = {'updrs_1': {'n_estimators': [100, 300, 500], 
                            'max_depth': [1, 3, 5, 10],
                            'criterion': ['absolute_error'],
                            'min_samples_split': [2, 5, 10],
                            'min_samples_leaf': [1, 2, 4],
                            'max_features': ['auto', 'sqrt', 'log2'],
                            'n_jobs': [2],
                            'random_state': [7656]
                            },

                'updrs_2': {'n_estimators': [100, 300, 500], 
                            'max_depth': [1, 3, 5, 10],
                            'criterion': ['absolute_error'],
                            'min_samples_split': [2, 5, 10],
                            'min_samples_leaf': [1, 2, 4],
                            'max_features': ['auto', 'sqrt', 'log2'],
                            'n_jobs': [2],
                            'random_state': [7656]
                            },

                'updrs_3': {'n_estimators': [100, 300, 500], 
                            'max_depth': [1, 3, 5, 10],
                            'criterion': ['absolute_error'],
                            'min_samples_split': [2, 5, 10],
                            'min_samples_leaf': [1, 2, 4],
                            'max_features': ['auto', 'sqrt', 'log2'],
                            'n_jobs': [2],
                            'random_state': [7656]
                            },

                'updrs_4': {'n_estimators': [100, 300, 500], 
                            'max_depth': [1, 3, 5, 10],
                            'criterion': ['absolute_error'],
                            'min_samples_split': [2, 5, 10],
                            'min_samples_leaf': [1, 2, 4],
                            'max_features': ['auto', 'sqrt', 'log2'],
                            'n_jobs': [2],
                            'random_state': [7656]
                            },
                            }

grids = {}

for col in y.columns:
    X_train = X[best_cols[col]]
    grid_search = GridSearchCV(RandomForestRegressor(), 
                               param_grid=xbgr_params[col], 
                               cv=5, 
                               scoring=smape, 
                               n_jobs=2,
                               verbose=1)

    grid_search.fit(X_train, y[col])
    grids[col] = {
                    'best_params': grid_search.best_params_, 
                    'best_score': grid_search.best_score_
                 }

    grid_data = pd.DataFrame(grid_search.cv_results_).sort_values(by='rank_test_score')[:10]
    grid_data.to_csv(f'../data/gridsearch/random_forest/3004-{k_best}best_log-norm-lag_grid_{col}_f_regr.csv')
# Out:
# Fitting 5 folds for each of 324 candidates, totalling 1620 fits
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_4005/3976518392.py in <module>
#      51                                verbose=1)
#      52
# ---> 53     grid_search.fit(X_train, y[col])
#      54     grids[col] = {
#      55                     'best_params': grid_search.best_params_,
#
# ~/anaconda3/envs/kaggle1/lib/python3.9/site-packages/sklearn/model_selection/_search.py in fit(self, X, y, groups, **fit_params)
#     889                 return results
#     890
# --> 891             self._run_search(evaluate_candidates)
#     892
#     893             # multimetric is determined here because in the case of a callable
#
# ~/anaconda3/envs/kaggle1/lib/python3.9/site-packages/sklearn/model_selection/_search.py in _run_search(self, evaluate_candidates)
#    1390     def _run_search(self, evaluate_candidates):
#    1391         """Search all candidates in param_grid"""
# -> 1392         evaluate_candidates(ParameterGrid(self.param_grid))
#    1393
#    1394
#
# ~/anaconda3/envs/kaggle1/lib/python3.9/site-packages/sklearn/model_selection/_search.py in evaluate_candidates(candidate_params, cv, more_results)
#     836                     )
#     837
# --> 838                 out = parallel(
#     839                     delayed(_fit_and_score)(
#     840                         clone(base_estimator),
#
# ~/anaconda3/envs/kaggle1/lib/python3.9/site-packages/joblib/parallel.py in __call__(self, iterable)
#    1054
#    1055             with self._backend.retrieval_context():
# -> 1056                 self.retrieve()
#    1057             # Make sure that we get a last message telling us we are done
#    1058             elapsed_time = time.time() - self._start_time
#
# ~/anaconda3/envs/kaggle1/lib/python3.9/site-packages/joblib/parallel.py in retrieve(self)
#     933             try:
#     934                 if getattr(self._backend, 'supports_timeout', False):
# --> 935                     self._output.extend(job.get(timeout=self.timeout))
#     936                 else:
#     937                     self._output.extend(job.get())
#
# ~/anaconda3/envs/kaggle1/lib/python3.9/site-packages/joblib/_parallel_backends.py in wrap_future_result(future, timeout)
#     540         AsyncResults.get from multiprocessing."""
#     541         try:
# --> 542             return future.result(timeout=timeout)
#     543         except CfTimeoutError as e:
#     544             raise TimeoutError from e
#
# ~/anaconda3/envs/kaggle1/lib/python3.9/concurrent/futures/_base.py in result(self, timeout)
#     439                     return self.__get_result()
#     440
# --> 441                 self._condition.wait(timeout)
#     442
#     443                 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# ~/anaconda3/envs/kaggle1/lib/python3.9/threading.py in wait(self, timeout)
#     310         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     311             if timeout is None:
# --> 312                 waiter.acquire()
#     313                 gotit = True
#     314             else:
#
# KeyboardInterrupt:
